# %% [markdown]
# <a href="https://colab.research.google.com/github/mmegias/IA3-UV/blob/main/dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006)

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (728)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Importar Keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model= Sequential()
#model.add(Dense((784, input_dim=784, activation='relu'))
model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],))) #input_shape= (tamaño de entrada, tamaño batch)
model.add(Dense(128,'relu'))
model.add(Dense(64,'relu'))
model.add(Dense(32,'relu'))
model.add(Dense(10,activation='softmax'))


# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 1s 5ms/step - loss: 0.5071 - accuracy: 0.8423 - val_loss: 0.2107 - val_accuracy: 0.9373
# Epoch 2/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1555 - accuracy: 0.9551 - val_loss: 0.1412 - val_accuracy: 0.9583
# Epoch 3/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1089 - accuracy: 0.9675 - val_loss: 0.1018 - val_accuracy: 0.9698
# Epoch 4/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0800 - accuracy: 0.9756 - val_loss: 0.0997 - val_accuracy: 0.9694
# Epoch 5/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0633 - accuracy: 0.9810 - val_loss: 0.0885 - val_accuracy: 0.9721
# Epoch 6/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0495 - accuracy: 0.9850 - val_loss: 0.0809 - val_accuracy: 0.9762
# Epoch 7/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9883 - val_loss: 0.0766 - val_accuracy: 0.9776
# Epoch 8/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9908 - val_loss: 0.0806 - val_accuracy: 0.9761
# Epoch 9/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9923 - val_loss: 0.0759 - val_accuracy: 0.9784
# Epoch 10/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9932 - val_loss: 0.0698 - val_accuracy: 0.9799
# Epoch 11/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.0812 - val_accuracy: 0.9781
# Epoch 12/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9962 - val_loss: 0.0749 - val_accuracy: 0.9797
# Epoch 13/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0765 - val_accuracy: 0.9795
# Epoch 14/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.0867 - val_accuracy: 0.9779
# Epoch 15/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 0.0981 - val_accuracy: 0.9742
# Epoch 16/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0793 - val_accuracy: 0.9801
# Epoch 17/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0814 - val_accuracy: 0.9805
# Epoch 18/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0844 - val_accuracy: 0.9791
# Epoch 19/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0860 - val_accuracy: 0.9801
# Epoch 20/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0898 - val_accuracy: 0.9798
# Epoch 21/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0891 - val_accuracy: 0.9786
# Epoch 22/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0896 - val_accuracy: 0.9792
# Epoch 23/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.1008 - val_accuracy: 0.9771
# Epoch 24/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.1024 - val_accuracy: 0.9774
# Epoch 25/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.0903 - val_accuracy: 0.9788
# Epoch 26/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0979 - val_accuracy: 0.9789
# Epoch 27/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0899 - val_accuracy: 0.9802
# Epoch 28/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0990 - val_accuracy: 0.9795
# Epoch 29/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.1114 - val_accuracy: 0.9770
# Epoch 30/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.1020 - val_accuracy: 0.9798
# Epoch 31/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.1118 - val_accuracy: 0.9788
# Epoch 32/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1031 - val_accuracy: 0.9809
# Epoch 33/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0998 - val_accuracy: 0.9792
# Epoch 34/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.1398 - val_accuracy: 0.9749
# Epoch 35/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.1095 - val_accuracy: 0.9797

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# Conclusion::  Viendo las gráficas se observa que el modelo sobreajusta, sobreaprende, overfitting

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
tf.keras.backend.clear_session()
n_epochs = 50
reg=tf.keras.regularizers.L1(0.001)

# Crear modelo
model_with_l2= Sequential()
model_with_l2.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],),kernel_regularizer=reg)) #input_shape= (tamaño de entrada, tamaño batch)
model_with_l2.add(Dense(128,'relu',kernel_regularizer=reg))
model_with_l2.add(Dense(64,'relu',kernel_regularizer=reg))
model_with_l2.add(Dense(32,'relu',kernel_regularizer=reg))
model_with_l2.add(Dense(10,activation='softmax'))

# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 1s 5ms/step - loss: 2.6516 - accuracy: 0.8290 - val_loss: 1.2373 - val_accuracy: 0.9014
# Epoch 2/50
# 118/118 [==============================] - 0s 4ms/step - loss: 1.0878 - accuracy: 0.9098 - val_loss: 0.9714 - val_accuracy: 0.9131
# Epoch 3/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.8997 - accuracy: 0.9204 - val_loss: 0.8289 - val_accuracy: 0.9280
# Epoch 4/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.8004 - accuracy: 0.9267 - val_loss: 0.7648 - val_accuracy: 0.9298
# Epoch 5/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.7443 - accuracy: 0.9300 - val_loss: 0.7012 - val_accuracy: 0.9364
# Epoch 6/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6964 - accuracy: 0.9324 - val_loss: 0.6784 - val_accuracy: 0.9332
# Epoch 7/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6692 - accuracy: 0.9332 - val_loss: 0.6509 - val_accuracy: 0.9357
# Epoch 8/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6387 - accuracy: 0.9367 - val_loss: 0.6228 - val_accuracy: 0.9386
# Epoch 9/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6178 - accuracy: 0.9380 - val_loss: 0.6051 - val_accuracy: 0.9389
# Epoch 10/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6008 - accuracy: 0.9396 - val_loss: 0.5876 - val_accuracy: 0.9412
# Epoch 11/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5849 - accuracy: 0.9408 - val_loss: 0.5792 - val_accuracy: 0.9402
# Epoch 12/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5694 - accuracy: 0.9430 - val_loss: 0.5634 - val_accuracy: 0.9412
# Epoch 13/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5532 - accuracy: 0.9444 - val_loss: 0.5461 - val_accuracy: 0.9452
# Epoch 14/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5430 - accuracy: 0.9453 - val_loss: 0.5349 - val_accuracy: 0.9452
# Epoch 15/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5350 - accuracy: 0.9457 - val_loss: 0.5250 - val_accuracy: 0.9457
# Epoch 16/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5174 - accuracy: 0.9492 - val_loss: 0.5256 - val_accuracy: 0.9442
# Epoch 17/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5114 - accuracy: 0.9482 - val_loss: 0.5148 - val_accuracy: 0.9466
# Epoch 18/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5057 - accuracy: 0.9484 - val_loss: 0.5056 - val_accuracy: 0.9457
# Epoch 19/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4931 - accuracy: 0.9496 - val_loss: 0.4867 - val_accuracy: 0.9492
# Epoch 20/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4847 - accuracy: 0.9507 - val_loss: 0.4787 - val_accuracy: 0.9511
# Epoch 21/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4764 - accuracy: 0.9515 - val_loss: 0.4773 - val_accuracy: 0.9489
# Epoch 22/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4703 - accuracy: 0.9506 - val_loss: 0.4691 - val_accuracy: 0.9510
# Epoch 23/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4637 - accuracy: 0.9513 - val_loss: 0.4607 - val_accuracy: 0.9525
# Epoch 24/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4564 - accuracy: 0.9527 - val_loss: 0.4820 - val_accuracy: 0.9426
# Epoch 25/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4502 - accuracy: 0.9527 - val_loss: 0.4546 - val_accuracy: 0.9478
# Epoch 26/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4439 - accuracy: 0.9527 - val_loss: 0.4431 - val_accuracy: 0.9527
# Epoch 27/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4409 - accuracy: 0.9533 - val_loss: 0.4479 - val_accuracy: 0.9485
# Epoch 28/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4304 - accuracy: 0.9553 - val_loss: 0.4305 - val_accuracy: 0.9534
# Epoch 29/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.9556 - val_loss: 0.4250 - val_accuracy: 0.9529
# Epoch 30/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4224 - accuracy: 0.9549 - val_loss: 0.4307 - val_accuracy: 0.9513
# Epoch 31/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4178 - accuracy: 0.9552 - val_loss: 0.4193 - val_accuracy: 0.9540
# Epoch 32/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4127 - accuracy: 0.9562 - val_loss: 0.4148 - val_accuracy: 0.9546
# Epoch 33/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4087 - accuracy: 0.9565 - val_loss: 0.4115 - val_accuracy: 0.9546
# Epoch 34/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4052 - accuracy: 0.9570 - val_loss: 0.4106 - val_accuracy: 0.9541
# Epoch 35/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4037 - accuracy: 0.9567 - val_loss: 0.4088 - val_accuracy: 0.9541
# Epoch 36/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4011 - accuracy: 0.9560 - val_loss: 0.3994 - val_accuracy: 0.9564
# Epoch 37/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.9574 - val_loss: 0.4146 - val_accuracy: 0.9512
# Epoch 38/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3940 - accuracy: 0.9579 - val_loss: 0.3962 - val_accuracy: 0.9556
# Epoch 39/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3945 - accuracy: 0.9570 - val_loss: 0.4005 - val_accuracy: 0.9542
# Epoch 40/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3895 - accuracy: 0.9574 - val_loss: 0.3905 - val_accuracy: 0.9550
# Epoch 41/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3840 - accuracy: 0.9586 - val_loss: 0.3877 - val_accuracy: 0.9561
# Epoch 42/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3840 - accuracy: 0.9585 - val_loss: 0.3837 - val_accuracy: 0.9574
# Epoch 43/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3804 - accuracy: 0.9590 - val_loss: 0.3833 - val_accuracy: 0.9572
# Epoch 44/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3790 - accuracy: 0.9589 - val_loss: 0.3847 - val_accuracy: 0.9554
# Epoch 45/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3766 - accuracy: 0.9590 - val_loss: 0.3894 - val_accuracy: 0.9530
# Epoch 46/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3735 - accuracy: 0.9591 - val_loss: 0.4021 - val_accuracy: 0.9499
# Epoch 47/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3747 - accuracy: 0.9588 - val_loss: 0.3842 - val_accuracy: 0.9548
# Epoch 48/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3680 - accuracy: 0.9596 - val_loss: 0.3721 - val_accuracy: 0.9577
# Epoch 49/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 0.9596 - val_loss: 0.3846 - val_accuracy: 0.9528
# Epoch 50/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3658 - accuracy: 0.9599 - val_loss: 0.3783 - val_accuracy: 0.9565

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
reg=None

# Crear modelo
model_dropout= Sequential()

model_dropout.add(Dense(256,'relu',input_shape=(X_train.shape[1],)))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(128,'relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(64,'relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(32,'relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(10,activation='softmax'))

# Compilamos el modelo
model_dropout.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_dropout.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 1s 5ms/step - loss: 0.4918 - accuracy: 0.8507 - val_loss: 0.1446 - val_accuracy: 0.9594
# Epoch 2/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1891 - accuracy: 0.9499 - val_loss: 0.1175 - val_accuracy: 0.9681
# Epoch 3/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9621 - val_loss: 0.1002 - val_accuracy: 0.9713
# Epoch 4/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1191 - accuracy: 0.9693 - val_loss: 0.0857 - val_accuracy: 0.9777
# Epoch 5/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0986 - accuracy: 0.9736 - val_loss: 0.0849 - val_accuracy: 0.9770
# Epoch 6/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0884 - accuracy: 0.9762 - val_loss: 0.0849 - val_accuracy: 0.9781
# Epoch 7/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.9799 - val_loss: 0.0869 - val_accuracy: 0.9775
# Epoch 8/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9821 - val_loss: 0.0850 - val_accuracy: 0.9786
# Epoch 9/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9830 - val_loss: 0.0831 - val_accuracy: 0.9804
# Epoch 10/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 0.9837 - val_loss: 0.0844 - val_accuracy: 0.9793
# Epoch 11/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9849 - val_loss: 0.0881 - val_accuracy: 0.9793
# Epoch 12/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9866 - val_loss: 0.0841 - val_accuracy: 0.9809
# Epoch 13/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9868 - val_loss: 0.0819 - val_accuracy: 0.9812
# Epoch 14/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0425 - accuracy: 0.9884 - val_loss: 0.0814 - val_accuracy: 0.9811
# Epoch 15/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0452 - accuracy: 0.9877 - val_loss: 0.0897 - val_accuracy: 0.9792
# Epoch 16/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 0.9891 - val_loss: 0.0824 - val_accuracy: 0.9816
# Epoch 17/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 0.9891 - val_loss: 0.0854 - val_accuracy: 0.9814
# Epoch 18/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9900 - val_loss: 0.0854 - val_accuracy: 0.9809
# Epoch 19/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9904 - val_loss: 0.0827 - val_accuracy: 0.9821
# Epoch 20/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9915 - val_loss: 0.0930 - val_accuracy: 0.9814
# Epoch 21/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9913 - val_loss: 0.0925 - val_accuracy: 0.9799
# Epoch 22/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0296 - accuracy: 0.9915 - val_loss: 0.0913 - val_accuracy: 0.9814
# Epoch 23/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 0.0916 - val_accuracy: 0.9812
# Epoch 24/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9916 - val_loss: 0.0963 - val_accuracy: 0.9798
# Epoch 25/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9921 - val_loss: 0.0841 - val_accuracy: 0.9831

# %%
model_dropout.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
plot_weights_hist(model_dropout)
plot_weights(model_dropout)

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
reg=None

# Crear modelo
model_dropout= Sequential()

model_dropout.add(Dropout(0.2,input_shape=(X_train.shape[1],)))
model_dropout.add(Dense(256,'relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(128,'relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(64,'relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(32,'relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(10,activation='softmax'))

# Compilamos el modelo
model_dropout.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_dropout.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 1s 5ms/step - loss: 0.5377 - accuracy: 0.8367 - val_loss: 0.1667 - val_accuracy: 0.9523
# Epoch 2/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.2362 - accuracy: 0.9386 - val_loss: 0.1212 - val_accuracy: 0.9657
# Epoch 3/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1878 - accuracy: 0.9493 - val_loss: 0.1086 - val_accuracy: 0.9692
# Epoch 4/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1583 - accuracy: 0.9576 - val_loss: 0.0989 - val_accuracy: 0.9730
# Epoch 5/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1378 - accuracy: 0.9633 - val_loss: 0.0815 - val_accuracy: 0.9780
# Epoch 6/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1255 - accuracy: 0.9665 - val_loss: 0.0851 - val_accuracy: 0.9756
# Epoch 7/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9685 - val_loss: 0.0781 - val_accuracy: 0.9782
# Epoch 8/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1102 - accuracy: 0.9707 - val_loss: 0.0766 - val_accuracy: 0.9787
# Epoch 9/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0996 - accuracy: 0.9726 - val_loss: 0.0724 - val_accuracy: 0.9793
# Epoch 10/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0974 - accuracy: 0.9727 - val_loss: 0.0731 - val_accuracy: 0.9804
# Epoch 11/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9741 - val_loss: 0.0717 - val_accuracy: 0.9805
# Epoch 12/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0864 - accuracy: 0.9761 - val_loss: 0.0718 - val_accuracy: 0.9808
# Epoch 13/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0816 - accuracy: 0.9771 - val_loss: 0.0709 - val_accuracy: 0.9814
# Epoch 14/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9779 - val_loss: 0.0715 - val_accuracy: 0.9805
# Epoch 15/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0794 - accuracy: 0.9790 - val_loss: 0.0707 - val_accuracy: 0.9828
# Epoch 16/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0725 - accuracy: 0.9794 - val_loss: 0.0672 - val_accuracy: 0.9826
# Epoch 17/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0715 - accuracy: 0.9802 - val_loss: 0.0669 - val_accuracy: 0.9823
# Epoch 18/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0716 - accuracy: 0.9801 - val_loss: 0.0663 - val_accuracy: 0.9828
# Epoch 19/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9809 - val_loss: 0.0648 - val_accuracy: 0.9834
# Epoch 20/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0641 - accuracy: 0.9817 - val_loss: 0.0715 - val_accuracy: 0.9830
# Epoch 21/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9818 - val_loss: 0.0655 - val_accuracy: 0.9826
# Epoch 22/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0623 - accuracy: 0.9822 - val_loss: 0.0690 - val_accuracy: 0.9819
# Epoch 23/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0599 - accuracy: 0.9830 - val_loss: 0.0638 - val_accuracy: 0.9840
# Epoch 24/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 0.9828 - val_loss: 0.0720 - val_accuracy: 0.9823
# Epoch 25/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 0.9826 - val_loss: 0.0699 - val_accuracy: 0.9828

# %%
model_dropout.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plots
plot_curves(hist.history)
plot_weights_hist(model_dropout)
plot_weights(model_dropout)
